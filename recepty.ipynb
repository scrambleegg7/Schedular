# %%
import pandas as pd
import os
import numpy as np

# %%
data_dir = "/home/donchan/Documents/DATA/miyuki"
test_file = "test.csv"

tokyo_file = "tokyo.csv"



test_csv = os.path.join(data_dir, test_file)
tokyo_csv = os.path.join(data_dir, tokyo_file)

# %%
col_names = [ 'c{0:02d}'.format(i) for i in range(82)  ]
print(col_names)
# Out:
# ['c00', 'c01', 'c02', 'c03', 'c04', 'c05', 'c06', 'c07', 'c08', 'c09', 'c10', 'c11', 'c12', 'c13', 'c14', 'c15', 'c16', 'c17', 'c18', 'c19', 'c20', 'c21', 'c22', 'c23', 'c24', 'c25', 'c26', 'c27', 'c28', 'c29', 'c30', 'c31', 'c32', 'c33', 'c34', 'c35', 'c36', 'c37', 'c38', 'c39', 'c40', 'c41', 'c42', 'c43', 'c44', 'c45', 'c46', 'c47', 'c48', 'c49', 'c50', 'c51', 'c52', 'c53', 'c54', 'c55', 'c56', 'c57', 'c58', 'c59', 'c60', 'c61', 'c62', 'c63', 'c64', 'c65', 'c66', 'c67', 'c68', 'c69', 'c70', 'c71', 'c72', 'c73', 'c74', 'c75', 'c76', 'c77', 'c78', 'c79', 'c80', 'c81']

# %%
df = pd.read_csv( test_csv, encoding="cp932" ,names=col_names)

np.unique(  df["c81"].values  )
# Out:
# array([nan, nan, nan, ..., nan, nan, nan])

# %%
pd.read_csv( tokyo_csv, encoding="cp932"  ,names=col_names)
# Out:
#     c00          c01        c02      c03        c04    c05        c06  c07  \
# 0    YK          1.0         13        4    1955244  みゆき薬局    50108.0  0.0
# 1    RE          1.0       4110    50107      宮下　直丈      1  3230704.0  NaN
# 2    HO    1130012.0   ４５０５０９１７        １          1    359        NaN  NaN
# 3    SH          1.0          5      NaN        NaN    118        NaN  NaN
# 4    CZ          1.0    5010701  5010701          1      1        1.0  1.0
# 5    IY          1.0  621779503       70        NaN    NaN        NaN  NaN
# 6    CO  810000001.0   １日１回・痛い所      NaN        NaN    NaN        NaN  NaN
# 7    CO  810000001.0    １日用量　１枚      NaN        NaN    NaN        NaN  NaN
# 8    SH          2.0          5      NaN        NaN     82        NaN  NaN
# 9    CZ          1.0    5010701  5010701          1      1        1.0  1.0
# 10   IY          1.0  620645301      120        NaN    NaN        NaN  NaN
# ...
